# %% [markdown]
# # LOCAL CONNECTION (output as SQL output)

# %%
#If you haven't installed it already (either by using pip or by anaconda), run the following command in a Jupyter Notebook cell to install the extension
#!pip install ipython-sql (i have commented it out since we already downloaded ipython-sql from anaconda)

# %%
#In a Jupyter Notebook cell, load the %sql extension using the %load_ext magic command:
# %load_ext sql

# %%
#Use the %sql magic command to connect to your SQLite database. 
#Replace your_database.db with the actual path to your SQLite database file. 
#Use forward slashes (/) as path separators even on Windows:
#db_path="C:/Users/DELL/Documents/All%20Files/ALX Academy/Data%20Science/SQL/SQL%20Files/Extracted%20Module-3-SQL-a-3902/Module%203_%20SQL/Exercises/chinook.db"
#db_path = "C:/Users/DELL/Documents/All Files/ALX Academy/Data Science/SQL/SQL Files/Extracted Module-3-SQL-a-3902/Module 3_ SQL/Exercises/chinook.db"
#%sql sqlite:///C:/Users/DELL/Documents/All%20Files/ALX%20Academy/Data%20Science/SQL/SQL%20Files/ALX%20SQL%20Tutorial1/Module3_%20SQL/Exercises/chinook.db

# %sql sqlite:///chinook.db
# Out:
# 'Connected: @chinook.db'

# %%
#This "%sql postgresql:///chinook.db" wont work for PostgreSQL does not use a single file for the entire database in the same way that SQLite does. Therefore, you cannot directly reference a "database filename" in the connection string as you might with SQLite.
#In PostgreSQL, you need to provide connection details such as the username, password, host, port, and database name in the connection string. The connection string format for PostgreSQL is typically:


#postgresql://username:password@host:port/database

# %%
#checking the table names in chinook database
#%sql SELECT name FROM sqlite_master WHERE type='table';

# %%
-- This is a single-line comment (SQL will not execute lines that begin with '--')

/* This is a block
comment which will comment
multiple lines
*/
# Out:
#   File "C:\Users\DELL\AppData\Local\Temp\ipykernel_17828\1299474431.py", line 1
#     -- This is a single-line comment (SQL will not execute lines that begin with '--')
#                  ^
# SyntaxError: invalid syntax

# %%
#Showing all tables present in the Chinook database
# %sql SELECT name FROM sqlite_master WHERE type='table';
# Out:
#  * sqlite:///chinook.db
# Done.
# [('albums',),
#  ('sqlite_sequence',),
#  ('artists',),
#  ('customers',),
#  ('employees',),
#  ('genres',),
#  ('invoices',),
#  ('invoice_items',),
#  ('media_types',),
#  ('playlists',),
#  ('playlist_track',),
#  ('tracks',),
#  ('sqlite_stat1',)]

# %%
#You can now execute SQL commands using the %sql magic command. For example, to retrieve data from a table:
#%reload_ext sql
#%sql SELECT * FROM "employees";
# %sql SELECT * FROM employees LIMIT 10;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 'Adams', 'Andrew', 'General Manager', None, '1962-02-18 00:00:00', '2002-08-14 00:00:00', '11120 Jasper Ave NW', 'Edmonton', 'AB', 'Canada', 'T5K 2N1', '+1 (780) 428-9482', '+1 (780) 428-3457', 'andrew@chinookcorp.com'),
#  (2, 'Edwards', 'Nancy', 'Sales Manager', 1, '1958-12-08 00:00:00', '2002-05-01 00:00:00', '825 8 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 2T3', '+1 (403) 262-3443', '+1 (403) 262-3322', 'nancy@chinookcorp.com'),
#  (3, 'Peacock', 'Jane', 'Sales Support Agent', 2, '1973-08-29 00:00:00', '2002-04-01 00:00:00', '1111 6 Ave SW', 'Calgary', 'AB', 'Canada', 'T2P 5M5', '+1 (403) 262-3443', '+1 (403) 262-6712', 'jane@chinookcorp.com'),
#  (4, 'Park', 'Margaret', 'Sales Support Agent', 2, '1947-09-19 00:00:00', '2003-05-03 00:00:00', '683 10 Street SW', 'Calgary', 'AB', 'Canada', 'T2P 5G3', '+1 (403) 263-4423', '+1 (403) 263-4289', 'margaret@chinookcorp.com'),
# ...

# %%
# %%sql
# SELECT
#     FirstName,
#     LastName,
#     Title
# FROM employees
# WHERE Country = 'Canada'
# AND City = 'Calgary'
# AND ReportsTo IS NOT NULL
# LIMIT 10;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('Nancy', 'Edwards', 'Sales Manager'),
#  ('Jane', 'Peacock', 'Sales Support Agent'),
#  ('Margaret', 'Park', 'Sales Support Agent'),
#  ('Steve', 'Johnson', 'Sales Support Agent'),
#  ('Michael', 'Mitchell', 'IT Manager')]

# %%
# %sql SELECT * FROM invoices LIMIT 10;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(1, 2, '2009-01-01 00:00:00', 'Theodor-Heuss-Straße 34', 'Stuttgart', None, 'Germany', '70174', 1.98),
#  (2, 4, '2009-01-02 00:00:00', 'Ullevålsveien 14', 'Oslo', None, 'Norway', '0171', 3.96),
#  (3, 8, '2009-01-03 00:00:00', 'Grétrystraat 63', 'Brussels', None, 'Belgium', '1000', 5.94),
#  (4, 14, '2009-01-06 00:00:00', '8210 111 ST NW', 'Edmonton', 'AB', 'Canada', 'T6G 2C7', 8.91),
#  (5, 23, '2009-01-11 00:00:00', '69 Salem Street', 'Boston', 'MA', 'USA', '2113', 13.86),
#  (6, 37, '2009-01-19 00:00:00', 'Berger Straße 10', 'Frankfurt', None, 'Germany', '60316', 0.99),
#  (7, 38, '2009-02-01 00:00:00', 'Barbarossastraße 19', 'Berlin', None, 'Germany', '10779', 1.98),
#  (8, 40, '2009-02-01 00:00:00', '8, Rue Hanovre', 'Paris', None, 'France', '75002', 1.98),
#  (9, 42, '2009-02-02 00:00:00', '9, Place Louis Barthou', 'Bordeaux', None, 'France', '33000', 3.96),
# ...

# %%
# %%sql
# SELECT
#     CustomerId,
#     BillingCountry,
#     ROUND(Total/SUM(Total) OVER (PARTITION BY BillingCountry)*100,2) AS pct_invoice_bill_by_country
# FROM invoices
# WHERE BillingCountry IS NOT NULL;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(56, 'Argentina', 5.26),
#  (56, 'Argentina', 10.53),
#  (56, 'Argentina', 15.79),
#  (56, 'Argentina', 2.63),
#  (56, 'Argentina', 5.26),
#  (56, 'Argentina', 36.84),
#  (56, 'Argentina', 23.68),
#  (55, 'Australia', 5.26),
#  (55, 'Australia', 10.53),
#  (55, 'Australia', 15.79),
#  (55, 'Australia', 2.63),
#  (55, 'Australia', 5.26),
#  (55, 'Australia', 36.84),
#  (55, 'Australia', 23.68),
#  (7, 'Austria', 4.65),
#  (7, 'Austria', 44.25),
#  (7, 'Austria', 20.91),
#  (7, 'Austria', 4.65),
#  (7, 'Austria', 9.29),
#  (7, 'Austria', 13.94),
#  (7, 'Austria', 2.32),
#  (8, 'Belgium', 15.79),
#  (8, 'Belgium', 2.63),
#  (8, 'Belgium', 5.26),
#  (8, 'Belgium', 36.84),
#  (8, 'Belgium', 23.68),
#  (8, 'Belgium', 5.26),
#  (8, 'Belgium', 10.53),
#  (10, 'Brazil', 4.69),
#  (12, 'Brazil', 0.52),
#  (13, 'Brazil', 1.04),
#  (11, 'Brazil', 1.04),
#  (13, 'Brazil', 2.08),
#  (11, 'Brazil', 7.29),
#  (13, 'Brazil', 3.12),
#  (1, 'Brazil', 2.09),
# ...

# %%
# %%sql
# SELECT
#     CustomerId,
#     BillingCountry,
#     ROUND(AVG(Total) OVER (PARTITION BY BillingCountry ORDER BY BillingCountry),2) AS Avg_Invoice_Amount
# FROM invoices
# WHERE Total IS NOT NULL;
# Out:
#  * sqlite:///chinook.db
# Done.
# [(56, 'Argentina', 5.37),
#  (56, 'Argentina', 5.37),
#  (56, 'Argentina', 5.37),
#  (56, 'Argentina', 5.37),
#  (56, 'Argentina', 5.37),
#  (56, 'Argentina', 5.37),
#  (56, 'Argentina', 5.37),
#  (55, 'Australia', 5.37),
#  (55, 'Australia', 5.37),
#  (55, 'Australia', 5.37),
#  (55, 'Australia', 5.37),
#  (55, 'Australia', 5.37),
#  (55, 'Australia', 5.37),
#  (55, 'Australia', 5.37),
#  (7, 'Austria', 6.09),
#  (7, 'Austria', 6.09),
#  (7, 'Austria', 6.09),
#  (7, 'Austria', 6.09),
#  (7, 'Austria', 6.09),
#  (7, 'Austria', 6.09),
#  (7, 'Austria', 6.09),
#  (8, 'Belgium', 5.37),
#  (8, 'Belgium', 5.37),
#  (8, 'Belgium', 5.37),
#  (8, 'Belgium', 5.37),
#  (8, 'Belgium', 5.37),
#  (8, 'Belgium', 5.37),
#  (8, 'Belgium', 5.37),
#  (10, 'Brazil', 5.43),
#  (12, 'Brazil', 5.43),
#  (13, 'Brazil', 5.43),
#  (11, 'Brazil', 5.43),
#  (13, 'Brazil', 5.43),
#  (11, 'Brazil', 5.43),
#  (13, 'Brazil', 5.43),
#  (1, 'Brazil', 5.43),
#  (1, 'Brazil', 5.43),
# ...

# %%
# %%sql
# SELECT c.FirstName AS "customer_name", c.LastName AS "customer_surname", e.FirstName AS "agent_name", e.LastName AS "agent_surname"
# FROM customers c, employees e
# WHERE c.Country = "Canada"
# AND c.SupportRepId = e.EmployeeId;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('François', 'Tremblay', 'Jane', 'Peacock'),
#  ('Mark', 'Philips', 'Steve', 'Johnson'),
#  ('Jennifer', 'Peterson', 'Jane', 'Peacock'),
#  ('Robert', 'Brown', 'Jane', 'Peacock'),
#  ('Edward', 'Francis', 'Jane', 'Peacock'),
#  ('Martha', 'Silk', 'Steve', 'Johnson'),
#  ('Aaron', 'Mitchell', 'Margaret', 'Park'),
#  ('Ellie', 'Sullivan', 'Jane', 'Peacock')]

# %%
# %%sql
#
# CREATE TABLE canadianemployees (
#   FirstName VARCHAR(50),
#   LastName VARCHAR(50),
#   AgentName VARCHAR(50),
#   AgentSurname VARCHAR(50)
# );
# Out:
#  * sqlite:///chinook.db
# (sqlite3.OperationalError) table canadianemployees already exists
# [SQL: CREATE TABLE canadianemployees (
#   FirstName VARCHAR(50),
#   LastName VARCHAR(50),
#   AgentName VARCHAR(50),
#   AgentSurname VARCHAR(50)
# );]
# (Background on this error at: https://sqlalche.me/e/14/e3q8)

# %%
# %%sql
#
# INSERT INTO canadianemployees (FirstName, LastName, AgentName, AgentSurname)
# SELECT c.FirstName AS "customer_name", c.LastName AS "customer_surname", e.FirstName AS "agent_name", e.LastName AS "agent_surname"
# FROM customers c, employees e
# WHERE c.Country = "Canada"
# AND c.SupportRepId = e.EmployeeId;
# Out:
#  * sqlite:///chinook.db
# 8 rows affected.
# []

# %%
# %sql SELECT * FROM canadianemployees;
# Out:
#  * sqlite:///chinook.db
# Done.
# [('François', 'Tremblay', 'Jane', 'Peacock'),
#  ('Mark', 'Philips', 'Steve', 'Johnson'),
#  ('Jennifer', 'Peterson', 'Jane', 'Peacock'),
#  ('Robert', 'Brown', 'Jane', 'Peacock'),
#  ('Edward', 'Francis', 'Jane', 'Peacock'),
#  ('Martha', 'Silk', 'Steve', 'Johnson'),
#  ('Aaron', 'Mitchell', 'Margaret', 'Park'),
#  ('Ellie', 'Sullivan', 'Jane', 'Peacock')]
